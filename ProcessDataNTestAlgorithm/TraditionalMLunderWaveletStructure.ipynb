# %% [markdown]
# ## Traditional ML classification models under wavelet analysis structures

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
import pandas as pd
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### SVM
# #### Read Data

# %%
# Configurations
LOWLUX = 'lowlux'
MIDLUX = 'middlelux'
HIGHLUX = 'highlux'
NOBACK = 'nothing'
ONEBACK = 'ONEBACK'
TWOBACK = 'TWOBACK'
THREEBACK = 'THREEBACK'
FILENAME = 'Filename'
IPA2 = 'IPA 2'
VALIDATIONSET = [1, 7, 14, 21, 24, 38, 40, 47]

# %%
# Read data and make them into processable formalities.
filepath = '../Data/Results/07-11-12-50/results.csv'
df_raw = pd.read_csv(filepath)
# df_raw

# %%
df_labels_IPA2 = df_raw[[FILENAME, IPA2]].copy()
df_labels_IPA2
# Out:
#                            Filename     IPA 2
# 0        05-10-13-15-lowlux-nothing  0.120845
# 1        05-10-13-17-lowlux-ONEBACK  0.294440
# 2        05-10-13-19-lowlux-TWOBACK  0.135787
# 3      05-10-13-21-lowlux-THREEBACK  0.372591
# 4       05-10-13-28-highlux-nothing  0.196893
# 5       05-10-13-30-highlux-ONEBACK  0.229213
# 6       05-10-13-33-highlux-TWOBACK  0.314535
# 7     05-10-13-36-highlux-THREEBACK  0.254980
# 8     06-10-13-59-middlelux-nothing  0.321147
# 9     06-10-14-01-middlelux-ONEBACK  0.228015
# 10    06-10-14-03-middlelux-TWOBACK  0.255581
# 11  06-10-14-05-middlelux-THREEBACK  0.271818
# 12      11-10-12-44-highlux-nothing  0.310617
# 13      11-10-12-47-highlux-ONEBACK  0.231318
# 14      11-10-12-49-highlux-TWOBACK  0.277697
# 15    11-10-12-51-highlux-THREEBACK  0.032975
# 16      11-10-12-56-highlux-nothing  0.202565
# 17      11-10-12-58-highlux-ONEBACK  0.031910
# 18      11-10-13-00-highlux-TWOBACK  0.265978
# 19    11-10-13-03-highlux-THREEBACK  0.170713
# 20    11-10-13-15-middlelux-nothing  0.206593
# 21    11-10-13-18-middlelux-ONEBACK  0.138440
# 22    11-10-13-19-middlelux-TWOBACK  0.089217
# 23  11-10-13-21-middlelux-THREEBACK  0.076351
# 24       11-10-13-39-lowlux-nothing  0.101101
# 25       11-10-13-42-lowlux-ONEBACK  0.077274
# 26       11-10-13-44-lowlux-TWOBACK  0.098780
# 27     11-10-13-48-lowlux-THREEBACK  0.094229
# 28      12-10-11-49-highlux-nothing  0.298786
# 29      12-10-11-51-highlux-ONEBACK  0.104010
# 30      12-10-11-55-highlux-TWOBACK  0.025840
# 31    12-10-12-01-highlux-THREEBACK  0.023315
# 32    12-10-12-06-middlelux-nothing  0.044239
# 33    12-10-12-09-middlelux-ONEBACK  0.220026
# 34    12-10-12-12-middlelux-TWOBACK  0.164489
# 35  12-10-12-15-middlelux-THREEBACK  0.191406
# 36      12-10-12-20-highlux-nothing  0.049753
# 37      12-10-12-22-highlux-ONEBACK  0.186316
# 38      12-10-12-26-highlux-TWOBACK  0.237620
# 39    12-10-12-30-highlux-THREEBACK  0.028747
# 40       23-09-14-58-lowlux-nothing  0.258967
# 41       23-09-15-01-lowlux-ONEBACK  0.087232
# 42       23-09-15-07-lowlux-TWOBACK  0.060754
# 43     23-09-15-12-lowlux-THREEBACK  0.042700
# 44       26-09-11-12-lowlux-nothing  0.225239
# 45       26-09-11-19-lowlux-ONEBACK  0.482222
# 46       26-09-11-29-lowlux-TWOBACK  0.351868
# 47     26-09-11-43-lowlux-THREEBACK  0.219460

# %%
# Labeling
luxes = []
nbacks = []
df_labels_IPA2 = df_labels_IPA2.reset_index()  # make sure indexes pair with number of rows
for index, row in df_labels_IPA2.iterrows():
    # Label luxes
    if LOWLUX in row[FILENAME]:
        luxes.append(10)
    elif MIDLUX in row[FILENAME]:
        luxes.append(20)
    elif HIGHLUX in row[FILENAME]:
        luxes.append(30)
    
    # Label task difficulties
    if NOBACK in row[FILENAME]:
        nbacks.append(0)
    elif ONEBACK in row[FILENAME]:
        nbacks.append(1)
    elif TWOBACK in row[FILENAME]:
        nbacks.append(2)
    elif THREEBACK in row[FILENAME]:
        nbacks.append(3)
df_labels_IPA2['LUX'] = luxes
df_labels_IPA2['nback_labels'] = nbacks

# %%
df_labels_IPA2
# Out:
#     index                         Filename     IPA 2  LUX  nback_labels
# 0       0       05-10-13-15-lowlux-nothing  0.120845   10             0
# 1       1       05-10-13-17-lowlux-ONEBACK  0.294440   10             1
# 2       2       05-10-13-19-lowlux-TWOBACK  0.135787   10             2
# 3       3     05-10-13-21-lowlux-THREEBACK  0.372591   10             3
# 4       4      05-10-13-28-highlux-nothing  0.196893   30             0
# 5       5      05-10-13-30-highlux-ONEBACK  0.229213   30             1
# 6       6      05-10-13-33-highlux-TWOBACK  0.314535   30             2
# 7       7    05-10-13-36-highlux-THREEBACK  0.254980   30             3
# 8       8    06-10-13-59-middlelux-nothing  0.321147   20             0
# 9       9    06-10-14-01-middlelux-ONEBACK  0.228015   20             1
# 10     10    06-10-14-03-middlelux-TWOBACK  0.255581   20             2
# 11     11  06-10-14-05-middlelux-THREEBACK  0.271818   20             3
# 12     12      11-10-12-44-highlux-nothing  0.310617   30             0
# 13     13      11-10-12-47-highlux-ONEBACK  0.231318   30             1
# 14     14      11-10-12-49-highlux-TWOBACK  0.277697   30             2
# 15     15    11-10-12-51-highlux-THREEBACK  0.032975   30             3
# 16     16      11-10-12-56-highlux-nothing  0.202565   30             0
# 17     17      11-10-12-58-highlux-ONEBACK  0.031910   30             1
# 18     18      11-10-13-00-highlux-TWOBACK  0.265978   30             2
# 19     19    11-10-13-03-highlux-THREEBACK  0.170713   30             3
# 20     20    11-10-13-15-middlelux-nothing  0.206593   20             0
# 21     21    11-10-13-18-middlelux-ONEBACK  0.138440   20             1
# 22     22    11-10-13-19-middlelux-TWOBACK  0.089217   20             2
# 23     23  11-10-13-21-middlelux-THREEBACK  0.076351   20             3
# 24     24       11-10-13-39-lowlux-nothing  0.101101   10             0
# 25     25       11-10-13-42-lowlux-ONEBACK  0.077274   10             1
# 26     26       11-10-13-44-lowlux-TWOBACK  0.098780   10             2
# 27     27     11-10-13-48-lowlux-THREEBACK  0.094229   10             3
# 28     28      12-10-11-49-highlux-nothing  0.298786   30             0
# 29     29      12-10-11-51-highlux-ONEBACK  0.104010   30             1
# 30     30      12-10-11-55-highlux-TWOBACK  0.025840   30             2
# 31     31    12-10-12-01-highlux-THREEBACK  0.023315   30             3
# 32     32    12-10-12-06-middlelux-nothing  0.044239   20             0
# 33     33    12-10-12-09-middlelux-ONEBACK  0.220026   20             1
# 34     34    12-10-12-12-middlelux-TWOBACK  0.164489   20             2
# 35     35  12-10-12-15-middlelux-THREEBACK  0.191406   20             3
# 36     36      12-10-12-20-highlux-nothing  0.049753   30             0
# 37     37      12-10-12-22-highlux-ONEBACK  0.186316   30             1
# 38     38      12-10-12-26-highlux-TWOBACK  0.237620   30             2
# 39     39    12-10-12-30-highlux-THREEBACK  0.028747   30             3
# 40     40       23-09-14-58-lowlux-nothing  0.258967   10             0
# 41     41       23-09-15-01-lowlux-ONEBACK  0.087232   10             1
# 42     42       23-09-15-07-lowlux-TWOBACK  0.060754   10             2
# 43     43     23-09-15-12-lowlux-THREEBACK  0.042700   10             3
# 44     44       26-09-11-12-lowlux-nothing  0.225239   10             0
# 45     45       26-09-11-19-lowlux-ONEBACK  0.482222   10             1
# 46     46       26-09-11-29-lowlux-TWOBACK  0.351868   10             2
# 47     47     26-09-11-43-lowlux-THREEBACK  0.219460   10             3

# %% [markdown]
# #### Model

# %%
# Split the data into training dataset and validation dataset.
# Training data
df_training = df_labels_IPA2.copy().drop(VALIDATIONSET, axis=0)
X_train = df_training[['IPA 2','LUX']].to_numpy()
y_train = df_training[['nback_labels']].to_numpy()
y_train = np.reshape(y_train, -1)
                                      
# Validation data 
df_validation = df_labels_IPA2.copy().loc[VALIDATIONSET]
X_test = df_validation[['IPA 2','LUX']].to_numpy()
y_test = df_validation[['nback_labels']].to_numpy()
y_test = np.reshape(y_test, -1)

# %%
# Try SVM, bacause it is one of the most widely used models in cognitive workload claissfications.
# X = np.array([[-1, -1], [-2, -1], [1, 1], [2, 1]])
# y = np.array([1, 1, 2, 2])
clf = make_pipeline(StandardScaler(), SVC(kernel='rbf', gamma='auto'))
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto'))])

# %%
y_pred = clf.predict(X_test)
print(y_pred, y_test)
# Out:
# [2 0 0 2 2 0 2 2] [1 3 2 1 0 2 0 3]

# %%
# Accuracy score calculation
accuracy_score(y_test, y_pred)
# Out:
# 0.0
